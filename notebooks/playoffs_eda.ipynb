# %%
import requests
import pandas as pd
from pathlib import Path
import logging
import os
import sys
from scipy.stats import zscore
import dataframe_image as dfi

current_dir = os.path.dirname(os.path.abspath("__file__"))
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))

if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)
from config.config import Config
from visualization.visualization import make_highlighted_table, team_styled_table

config = Config()

# %%
def fetch_playoff_player_stats(group_id, token=config._ballchasing_token):

    url = f"https://ballchasing.com/api/groups/{group_id}"
    headers = {"Authorization": token}
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    data = response.json()
    df = pd.json_normalize(data, record_path=["players"])
    return df

# %%
def fetch_playoff_team_stats(group_id, token=config._ballchasing_token):

    url = f"https://ballchasing.com/api/groups/{group_id}"
    headers = {"Authorization": token}
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    data = response.json()
    df = pd.json_normalize(data, record_path=["teams"])
    return df

# %%
def process():
    df = fetch_playoff_player_stats(config._playoff_group_url)
    
    features_to_keep = [
        "name",
        "team",
        "game_average.core.score",
        "game_average.core.goals",
        "game_average.core.assists",
        "game_average.core.saves",
        "game_average.core.shots",
        "game_average.core.shooting_percentage",
        "game_average.demo.inflicted",
        "game_average.demo.taken",
        "game_average.boost.amount_stolen_big",
        "game_average.boost.amount_stolen_small",
    ]

    df_final = df[features_to_keep].copy()
    df_final.columns = ["Player", "Team", "Avg Score", "Goals Per Game", "Assists Per Game", "Saves Per Game", "Shots Per Game", "Shooting %", "Demos Inf. Per Game", "Demos Taken Per Game", "Big Boost Stolen", "Small Boost Stolen"]

    df_final2 = df_final.copy()
    df_final2 = df_final2.drop("Team", axis=1)
    logging.info("Calculating Z-scores and Dominance Quotient for players...")
    df_final2["Avg Score Zscore"] = round(zscore(df_final2["Avg Score"]) * config.avg_score, 2)
    df_final2["Goals Per Game Zscore"] = round(zscore(df_final2["Goals Per Game"]) * config.goals_per_game, 2)
    df_final2["Assists Per Game Zscore"] = round(zscore(df_final2["Assists Per Game"]) * config.assists_per_game, 2)
    df_final2["Saves Per Game Zscore"] = round(zscore(df_final2["Saves Per Game"]) * config.saves_per_game, 2)
    df_final2["Shots Per Game Zscore"] = round(zscore(df_final2["Shots Per Game"]) * config.shots_per_game, 2)
    df_final2["Demos Inf. Per Game Zscore"] = round(zscore(df_final2["Demos Inf. Per Game"]) * config.demos_per_games, 2)
    df_final2["Demos Taken Per Game Zscore"] = round(zscore(df_final2["Demos Taken Per Game"]) * config.demos_taken_per_game, 2)
    df_final2["Big Boost Stolen Zscore"] = round(zscore(df_final2["Big Boost Stolen"]) * config.count_big_pads_stolen_per_game, 2)
    df_final2["Small Boost Stolen Zscore"] = round(zscore(df_final2["Small Boost Stolen"]) * config.count_small_pads_stolen_per_game, 2)
    df_final2["Shooting %"] = df_final2["Shooting %"] / 100

    # Calculate Dominance Quotient
    dq_summation = [i for i in df_final2.columns.tolist() if "Zscore" in i]
    df_final2["Dominance Quotient"] = df_final2[dq_summation].sum(axis=1) * 50

    df_final2 = df_final2[["Player", "Dominance Quotient", "Avg Score", "Goals Per Game", "Assists Per Game", "Saves Per Game", "Shots Per Game", "Shooting %", "Demos Inf. Per Game", "Demos Taken Per Game", "Big Boost Stolen", "Small Boost Stolen"]]

    df_final2 = df_final2.sort_values(by="Dominance Quotient", ascending=False).reset_index(drop=True)
    df_final2.index += 1

    return df_final2, df_final

# %%
def filter_player_data():
    """Filter the data."""
    # Load the data
    df_final2, df_final = process()

    logging.info("Calculating Z-scores and Dominance Quotient for players...")
    df_final2["Avg Score Zscore"] = round(zscore(df_final2["Avg Score"]) * config.avg_score, 2)
    df_final2["Goals Per Game Zscore"] = round(zscore(df_final2["Goals Per Game"]) * config.goals_per_game, 2)
    df_final2["Assists Per Game Zscore"] = round(zscore(df_final2["Assists Per Game"]) * config.assists_per_game, 2)
    df_final2["Saves Per Game Zscore"] = round(zscore(df_final2["Saves Per Game"]) * config.saves_per_game, 2)
    df_final2["Shots Per Game Zscore"] = round(zscore(df_final2["Shots Per Game"]) * config.shots_per_game, 2)
    df_final2["Demos Inf. Per Game Zscore"] = round(zscore(df_final2["Demos Inf. Per Game"]) * config.demos_per_games, 2)
    df_final2["Demos Taken Per Game Zscore"] = round(zscore(df_final2["Demos Taken Per Game"]) * config.demos_taken_per_game, 2)
    df_final2["Big Boost Stolen Zscore"] = round(zscore(df_final2["Big Boost Stolen"]) * config.count_big_pads_stolen_per_game, 2)
    df_final2["Small Boost Stolen Zscore"] = round(zscore(df_final2["Small Boost Stolen"]) * config.count_small_pads_stolen_per_game, 2)

    # for styling purposes
    df_final2["Shooting %"] = df_final2["Shooting %"] / 100

    # Calculate Dominance Quotient
    dq_summation = [i for i in df_final2.columns.tolist() if "Zscore" in i]
    df_final2["Dominance Quotient"] = df_final2[dq_summation].sum(axis=1) * 50
    df_final2 = df_final2[["Player", "Dominance Quotient", "Avg Score", "Goals Per Game", "Assists Per Game", "Saves Per Game", "Shots Per Game", "Shooting %", "Demos Inf. Per Game", "Demos Taken Per Game", "Big Boost Stolen", "Small Boost Stolen"]]
    df_final2 = df_final2.sort_values(by="Dominance Quotient", ascending=False).reset_index(drop=True)
    df_final2.index += 1

    # Save the cleaned data to a parquet file
    df_final2.to_parquet("../data/parquet/playoff_player_data_season_2.parquet")

    # highlighted table
    styled_player_df = make_highlighted_table(df_final2)
    dfi.export(styled_player_df, "../images/playoff_player_data_season_2.png")
    logging.info(f"Player DataFrame image exported")

    return styled_player_df, df_final2, df_final

# %%
def filter_team_data():
    """Filter the data."""
    team_df = fetch_playoff_team_stats(group_id=config._playoff_group_url)
    styled_player_data, df_final2, df_final = filter_player_data()
    # Load the data
    team_df = team_df.sort_values(by="name").reset_index(drop=True)
    team_df["Goal Diff"] = team_df["cumulative.core.goals"] - team_df["cumulative.core.goals_against"]
    team_df["Demo Diff"] = team_df["cumulative.demo.inflicted"] - team_df["cumulative.demo.taken"]
    team_df["Shots Diff"] = team_df["cumulative.core.shots"] - team_df["cumulative.core.shots_against"]
    team_df["Win % Zscore"] = zscore(team_df["cumulative.win_percentage"]) * config.win_perc_weight
    team_df["Goal Diff Zscore"] = zscore(team_df["Goal Diff"]) * config.goal_diff_weight
    team_df["Demo Diff Zscore"] = zscore(team_df["Demo Diff"]) * config.demo_diff_weight
    team_df["Shots Diff Zscore"] = zscore(team_df["Shots Diff"]) * config.shot_diff_weight

    # Calculate EPI Score
    team_df["EPI Score"] = team_df[[
        "Win % Zscore", 
        "Goal Diff Zscore", 
        "Demo Diff Zscore", 
        "Shots Diff Zscore", 
        # "Team Played Win % Zscore"
    ]].sum(axis=1)

    features_of_interest = ["name", "cumulative.win_percentage", "game_average.core.goals", "game_average.core.goals_against", "cumulative.core.goals", 
                        "cumulative.core.goals_against", "game_average.core.shots", "game_average.core.shots_against", "cumulative.core.shots", "cumulative.core.shots_against", "EPI Score"
                        ]
    
    team_df = team_df[features_of_interest]

    team_df["Goal Diff"] = team_df.loc[:, "cumulative.core.goals"] - team_df.loc[:, "cumulative.core.goals_against"]
    team_df["Shot Diff"] = team_df.loc[:, "cumulative.core.shots"] - team_df.loc[:, "cumulative.core.shots_against"]

    team_df = team_df.drop(columns=["cumulative.core.goals", "cumulative.core.goals_against", "cumulative.core.shots", "cumulative.core.shots_against"], axis=1)

    team_df.columns = ["Team", "Win %", "Goals For", "Goals Against", "Shots For", "Shots Against", "EPI Score", "Goal Diff", "Shot Diff"]

    team_df = team_df[["Team", "EPI Score", "Win %", "Goals For", "Goals Against", "Goal Diff", "Shots For", "Shots Against", "Shot Diff"]]

    df_final3 = df_final.copy()
    df_final3["Dominance Quotient"] = df_final3["Player"].map(df_final2.set_index("Player")["Dominance Quotient"])

    # Calculate Roster Rating
    player_dq_summation = df_final3.groupby("Team")["Dominance Quotient"].sum().reset_index()
    player_dq_summation_zipped = dict(zip(player_dq_summation["Team"], player_dq_summation["Dominance Quotient"]))
    df_final3["Roster Rating"] = df_final3["Team"].map(player_dq_summation_zipped)

    df_final3 = df_final3.drop("Player", axis=1)
    df_final3 = df_final3.groupby("Team")["Roster Rating"].mean().reset_index()

    df_final3 = df_final3.sort_values(by="Roster Rating", ascending=False).reset_index(drop=True)

    team_df = team_df.merge(df_final3, on="Team", how="left")

    team_df["EPI Score"] = round(team_df["EPI Score"] * 50, 2)

    team_df = team_df[["Team", "EPI Score", "Roster Rating", "Win %", "Goals For", "Goals Against", "Goal Diff", "Shots For", "Shots Against", "Shot Diff"]]

    team_df["Goal Diff"] = team_df["Goal Diff"].apply(lambda x: str(f"{x}") if x < 0 else f"+{x}")
    team_df["Shot Diff"] = team_df["Shot Diff"].apply(lambda x: str(f"{x}") if x < 0 else f"+{x}")

    # round win% to no decimal places
    team_df["Win %"] = round(team_df["Win %"]).astype(int)
    team_df["Win %"] = team_df["Win %"].apply(lambda x: f"{x}%")

    for col in team_df.select_dtypes(include="number"):
        if col != "EPI Score":
            team_df[col] = team_df[col].round(2)
        else:
            continue

    team_df = team_df.sort_values(by="EPI Score", ascending=False).reset_index(drop=True)
    team_df.index += 1

    team_df.to_parquet("../data/parquet/playoff_team_data_season_2.parquet")
    team_df.to_csv("../data/parquet/playoff_team_data_season_2.csv")

    styled_team_df = team_styled_table(team_df)
    dfi.export(styled_team_df, "../images/playoff_team_data_season_2.png")

    return styled_team_df, styled_player_data

# %%
styled_team_df, styled_player_data = filter_team_data()

# %%
styled_team_df
# Out:
# <style type="text/css">
# #T_7e49c thead th {
#   color: #f8f8f2;
#   background-color: #282a36;
# }
# #T_7e49c tbody tr:nth-child(even) td {
#   background-color: #44475a;
#   color: #f8f8f2;
# }
# #T_7e49c  tbody tr:nth-child(even) th {
#   background-color: #44475a;
#   color: #f8f8f2;
# }
# #T_7e49c tbody tr:nth-child(odd) td {
#   background-color: #282a36;
#   color: #f8f8f2;
# }
# #T_7e49c  tbody tr:nth-child(odd) th {
#   background-color: #282a36;
#   color: #f8f8f2;
# }
# #T_7e49c td {
#   border: none;
# }
# #T_7e49c  th {
#   border: none;
# }
# </style>
# <table id="T_7e49c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e49c_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_7e49c_level0_col1" class="col_heading level0 col1" >EPI Score</th>
#       <th id="T_7e49c_level0_col2" class="col_heading level0 col2" >Roster Rating</th>
#       <th id="T_7e49c_level0_col3" class="col_heading level0 col3" >Win %</th>
#       <th id="T_7e49c_level0_col4" class="col_heading level0 col4" >Goals For</th>
#       <th id="T_7e49c_level0_col5" class="col_heading level0 col5" >Goals Against</th>
#       <th id="T_7e49c_level0_col6" class="col_heading level0 col6" >Goal Diff</th>
#       <th id="T_7e49c_level0_col7" class="col_heading level0 col7" >Shots For</th>
#       <th id="T_7e49c_level0_col8" class="col_heading level0 col8" >Shots Against</th>
#       <th id="T_7e49c_level0_col9" class="col_heading level0 col9" >Shot Diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e49c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7e49c_row0_col0" class="data row0 col0" >MINORITIES</td>
#       <td id="T_7e49c_row0_col1" class="data row0 col1" >90.67</td>
#       <td id="T_7e49c_row0_col2" class="data row0 col2" >52.00</td>
#       <td id="T_7e49c_row0_col3" class="data row0 col3" >89%</td>
#       <td id="T_7e49c_row0_col4" class="data row0 col4" >2.78</td>
#       <td id="T_7e49c_row0_col5" class="data row0 col5" >1.33</td>
#       <td id="T_7e49c_row0_col6" class="data row0 col6" >+13</td>
#       <td id="T_7e49c_row0_col7" class="data row0 col7" >8.11</td>
#       <td id="T_7e49c_row0_col8" class="data row0 col8" >6.22</td>
#       <td id="T_7e49c_row0_col9" class="data row0 col9" >+17</td>
#     </tr>
#     <tr>
#       <th id="T_7e49c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7e49c_row1_col0" class="data row1 col0" >EXECUTIVE PROJEC</td>
#       <td id="T_7e49c_row1_col1" class="data row1 col1" >11.80</td>
#       <td id="T_7e49c_row1_col2" class="data row1 col2" >-12.50</td>
#       <td id="T_7e49c_row1_col3" class="data row1 col3" >55%</td>
#       <td id="T_7e49c_row1_col4" class="data row1 col4" >2.18</td>
#       <td id="T_7e49c_row1_col5" class="data row1 col5" >1.91</td>
#       <td id="T_7e49c_row1_col6" class="data row1 col6" >+3</td>
#       <td id="T_7e49c_row1_col7" class="data row1 col7" >7.27</td>
#       <td id="T_7e49c_row1_col8" class="data row1 col8" >9.00</td>
#       <td id="T_7e49c_row1_col9" class="data row1 col9" >-19</td>
#     </tr>
#     <tr>
#       <th id="T_7e49c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7e49c_row2_col0" class="data row2 col0" >WONDER PETS</td>
#       <td id="T_7e49c_row2_col1" class="data row2 col1" >9.88</td>
#       <td id="T_7e49c_row2_col2" class="data row2 col2" >-52.00</td>
#       <td id="T_7e49c_row2_col3" class="data row2 col3" >50%</td>
#       <td id="T_7e49c_row2_col4" class="data row2 col4" >1.75</td>
#       <td id="T_7e49c_row2_col5" class="data row2 col5" >1.58</td>
#       <td id="T_7e49c_row2_col6" class="data row2 col6" >+2</td>
#       <td id="T_7e49c_row2_col7" class="data row2 col7" >7.75</td>
#       <td id="T_7e49c_row2_col8" class="data row2 col8" >8.17</td>
#       <td id="T_7e49c_row2_col9" class="data row2 col9" >-5</td>
#     </tr>
#     <tr>
#       <th id="T_7e49c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_7e49c_row3_col0" class="data row3 col0" >KILLER BS</td>
#       <td id="T_7e49c_row3_col1" class="data row3 col1" >2.42</td>
#       <td id="T_7e49c_row3_col2" class="data row3 col2" >24.50</td>
#       <td id="T_7e49c_row3_col3" class="data row3 col3" >50%</td>
#       <td id="T_7e49c_row3_col4" class="data row3 col4" >2.00</td>
#       <td id="T_7e49c_row3_col5" class="data row3 col5" >2.30</td>
#       <td id="T_7e49c_row3_col6" class="data row3 col6" >-3</td>
#       <td id="T_7e49c_row3_col7" class="data row3 col7" >9.20</td>
#       <td id="T_7e49c_row3_col8" class="data row3 col8" >8.00</td>
#       <td id="T_7e49c_row3_col9" class="data row3 col9" >+12</td>
#     </tr>
#     <tr>
#       <th id="T_7e49c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_7e49c_row4_col0" class="data row4 col0" >DIDDLERS</td>
#       <td id="T_7e49c_row4_col1" class="data row4 col1" >-3.59</td>
#       <td id="T_7e49c_row4_col2" class="data row4 col2" >-16.50</td>
#       <td id="T_7e49c_row4_col3" class="data row4 col3" >45%</td>
#       <td id="T_7e49c_row4_col4" class="data row4 col4" >1.73</td>
#       <td id="T_7e49c_row4_col5" class="data row4 col5" >1.91</td>
#       <td id="T_7e49c_row4_col6" class="data row4 col6" >-2</td>
#       <td id="T_7e49c_row4_col7" class="data row4 col7" >8.18</td>
#       <td id="T_7e49c_row4_col8" class="data row4 col8" >7.27</td>
#       <td id="T_7e49c_row4_col9" class="data row4 col9" >+10</td>
#     </tr>
#     <tr>
#       <th id="T_7e49c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_7e49c_row5_col0" class="data row5 col0" >SCAVS</td>
#       <td id="T_7e49c_row5_col1" class="data row5 col1" >-13.20</td>
#       <td id="T_7e49c_row5_col2" class="data row5 col2" >14.50</td>
#       <td id="T_7e49c_row5_col3" class="data row5 col3" >44%</td>
#       <td id="T_7e49c_row5_col4" class="data row5 col4" >2.11</td>
#       <td id="T_7e49c_row5_col5" class="data row5 col5" >2.56</td>
#       <td id="T_7e49c_row5_col6" class="data row5 col6" >-4</td>
#       <td id="T_7e49c_row5_col7" class="data row5 col7" >8.00</td>
#       <td id="T_7e49c_row5_col8" class="data row5 col8" >9.22</td>
#       <td id="T_7e49c_row5_col9" class="data row5 col9" >-11</td>
#     </tr>
#     <tr>
#       <th id="T_7e49c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_7e49c_row6_col0" class="data row6 col0" >PUSHIN PULLIS</td>
#       <td id="T_7e49c_row6_col1" class="data row6 col1" >-47.42</td>
#       <td id="T_7e49c_row6_col2" class="data row6 col2" >-4.00</td>
#       <td id="T_7e49c_row6_col3" class="data row6 col3" >20%</td>
#       <td id="T_7e49c_row6_col4" class="data row6 col4" >1.60</td>
#       <td id="T_7e49c_row6_col5" class="data row6 col5" >2.00</td>
#       <td id="T_7e49c_row6_col6" class="data row6 col6" >-2</td>
#       <td id="T_7e49c_row6_col7" class="data row6 col7" >6.60</td>
#       <td id="T_7e49c_row6_col8" class="data row6 col8" >9.60</td>
#       <td id="T_7e49c_row6_col9" class="data row6 col9" >-15</td>
#     </tr>
#     <tr>
#       <th id="T_7e49c_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_7e49c_row7_col0" class="data row7 col0" >BECKYARDIGANS</td>
#       <td id="T_7e49c_row7_col1" class="data row7 col1" >-50.56</td>
#       <td id="T_7e49c_row7_col2" class="data row7 col2" >-7.50</td>
#       <td id="T_7e49c_row7_col3" class="data row7 col3" >20%</td>
#       <td id="T_7e49c_row7_col4" class="data row7 col4" >1.80</td>
#       <td id="T_7e49c_row7_col5" class="data row7 col5" >3.20</td>
#       <td id="T_7e49c_row7_col6" class="data row7 col6" >-7</td>
#       <td id="T_7e49c_row7_col7" class="data row7 col7" >10.40</td>
#       <td id="T_7e49c_row7_col8" class="data row7 col8" >8.20</td>
#       <td id="T_7e49c_row7_col9" class="data row7 col9" >+11</td>
#     </tr>
#   </tbody>
# </table>

# %%
styled_player_data
# Out:
# <style type="text/css">
# #T_90ad4 thead th {
#   color: #f8f8f2;
#   background-color: #282a36;
# }
# #T_90ad4 tbody tr:nth-child(even) td {
#   background-color: #44475a;
# }
# #T_90ad4  tbody tr:nth-child(even) th {
#   background-color: #44475a;
# }
# #T_90ad4 tbody tr:nth-child(odd) td {
#   background-color: #282a36;
# }
# #T_90ad4  tbody tr:nth-child(odd) th {
#   background-color: #282a36;
# }
# #T_90ad4 td {
#   border: none;
#   text-align: center;
# }
# #T_90ad4  th {
#   border: none;
#   text-align: center;
# }
# #T_90ad4 .row_heading {
#   color: #f8f8f2;
#   background-color: #282a36;
# }
# #T_90ad4  .blank {
#   color: #f8f8f2;
#   background-color: #282a36;
# }
# #T_90ad4_row0_col0, #T_90ad4_row0_col1, #T_90ad4_row0_col4, #T_90ad4_row0_col6, #T_90ad4_row0_col7, #T_90ad4_row0_col8, #T_90ad4_row0_col9, #T_90ad4_row0_col10, #T_90ad4_row0_col11, #T_90ad4_row1_col0, #T_90ad4_row1_col1, #T_90ad4_row1_col2, #T_90ad4_row1_col3, #T_90ad4_row1_col4, #T_90ad4_row1_col5, #T_90ad4_row1_col7, #T_90ad4_row1_col8, #T_90ad4_row1_col11, #T_90ad4_row2_col0, #T_90ad4_row2_col1, #T_90ad4_row2_col2, #T_90ad4_row2_col3, #T_90ad4_row2_col4, #T_90ad4_row2_col5, #T_90ad4_row2_col6, #T_90ad4_row2_col7, #T_90ad4_row2_col8, #T_90ad4_row2_col9, #T_90ad4_row2_col10, #T_90ad4_row2_col11, #T_90ad4_row3_col0, #T_90ad4_row3_col1, #T_90ad4_row3_col2, #T_90ad4_row3_col3, #T_90ad4_row3_col4, #T_90ad4_row3_col5, #T_90ad4_row3_col6, #T_90ad4_row3_col7, #T_90ad4_row3_col8, #T_90ad4_row3_col9, #T_90ad4_row3_col10, #T_90ad4_row3_col11, #T_90ad4_row4_col0, #T_90ad4_row4_col1, #T_90ad4_row4_col2, #T_90ad4_row4_col3, #T_90ad4_row4_col4, #T_90ad4_row4_col5, #T_90ad4_row4_col6, #T_90ad4_row4_col7, #T_90ad4_row4_col8, #T_90ad4_row4_col9, #T_90ad4_row4_col10, #T_90ad4_row5_col0, #T_90ad4_row5_col1, #T_90ad4_row5_col2, #T_90ad4_row5_col3, #T_90ad4_row5_col4, #T_90ad4_row5_col5, #T_90ad4_row5_col6, #T_90ad4_row5_col7, #T_90ad4_row5_col8, #T_90ad4_row5_col10, #T_90ad4_row5_col11, #T_90ad4_row6_col0, #T_90ad4_row6_col1, #T_90ad4_row6_col2, #T_90ad4_row6_col3, #T_90ad4_row6_col4, #T_90ad4_row6_col5, #T_90ad4_row6_col6, #T_90ad4_row6_col7, #T_90ad4_row6_col8, #T_90ad4_row6_col9, #T_90ad4_row6_col10, #T_90ad4_row6_col11, #T_90ad4_row7_col0, #T_90ad4_row7_col1, #T_90ad4_row7_col2, #T_90ad4_row7_col3, #T_90ad4_row7_col4, #T_90ad4_row7_col5, #T_90ad4_row7_col6, #T_90ad4_row7_col7, #T_90ad4_row7_col8, #T_90ad4_row7_col9, #T_90ad4_row7_col10, #T_90ad4_row7_col11, #T_90ad4_row8_col0, #T_90ad4_row8_col1, #T_90ad4_row8_col2, #T_90ad4_row8_col3, #T_90ad4_row8_col4, #T_90ad4_row8_col5, #T_90ad4_row8_col6, #T_90ad4_row8_col7, #T_90ad4_row8_col8, #T_90ad4_row8_col9, #T_90ad4_row8_col10, #T_90ad4_row8_col11, #T_90ad4_row9_col0, #T_90ad4_row9_col1, #T_90ad4_row9_col2, #T_90ad4_row9_col3, #T_90ad4_row9_col6, #T_90ad4_row9_col7, #T_90ad4_row9_col8, #T_90ad4_row9_col9, #T_90ad4_row9_col10, #T_90ad4_row9_col11, #T_90ad4_row10_col0, #T_90ad4_row10_col1, #T_90ad4_row10_col2, #T_90ad4_row10_col3, #T_90ad4_row10_col4, #T_90ad4_row10_col5, #T_90ad4_row10_col6, #T_90ad4_row10_col7, #T_90ad4_row10_col8, #T_90ad4_row10_col9, #T_90ad4_row10_col11, #T_90ad4_row11_col0, #T_90ad4_row11_col1, #T_90ad4_row11_col2, #T_90ad4_row11_col3, #T_90ad4_row11_col4, #T_90ad4_row11_col5, #T_90ad4_row11_col6, #T_90ad4_row11_col7, #T_90ad4_row11_col8, #T_90ad4_row11_col9, #T_90ad4_row11_col10, #T_90ad4_row11_col11, #T_90ad4_row12_col0, #T_90ad4_row12_col1, #T_90ad4_row12_col2, #T_90ad4_row12_col3, #T_90ad4_row12_col5, #T_90ad4_row12_col6, #T_90ad4_row12_col7, #T_90ad4_row12_col9, #T_90ad4_row12_col10, #T_90ad4_row12_col11, #T_90ad4_row13_col0, #T_90ad4_row13_col1, #T_90ad4_row13_col2, #T_90ad4_row13_col3, #T_90ad4_row13_col4, #T_90ad4_row13_col5, #T_90ad4_row13_col6, #T_90ad4_row13_col7, #T_90ad4_row13_col8, #T_90ad4_row13_col9, #T_90ad4_row13_col10, #T_90ad4_row13_col11, #T_90ad4_row14_col0, #T_90ad4_row14_col1, #T_90ad4_row14_col2, #T_90ad4_row14_col3, #T_90ad4_row14_col4, #T_90ad4_row14_col5, #T_90ad4_row14_col6, #T_90ad4_row14_col7, #T_90ad4_row14_col8, #T_90ad4_row14_col9, #T_90ad4_row14_col10, #T_90ad4_row14_col11, #T_90ad4_row15_col0, #T_90ad4_row15_col1, #T_90ad4_row15_col2, #T_90ad4_row15_col3, #T_90ad4_row15_col4, #T_90ad4_row15_col5, #T_90ad4_row15_col6, #T_90ad4_row15_col8, #T_90ad4_row15_col9, #T_90ad4_row15_col10, #T_90ad4_row15_col11, #T_90ad4_row16_col0, #T_90ad4_row16_col1, #T_90ad4_row16_col2, #T_90ad4_row16_col3, #T_90ad4_row16_col4, #T_90ad4_row16_col5, #T_90ad4_row16_col6, #T_90ad4_row16_col7, #T_90ad4_row16_col8, #T_90ad4_row16_col9, #T_90ad4_row16_col10, #T_90ad4_row16_col11, #T_90ad4_row17_col0, #T_90ad4_row17_col1, #T_90ad4_row17_col2, #T_90ad4_row17_col3, #T_90 ...
#   color: #f8f8f2;
#   text-align: center;
# }
# #T_90ad4_row0_col2, #T_90ad4_row0_col3, #T_90ad4_row0_col5, #T_90ad4_row1_col6, #T_90ad4_row1_col9, #T_90ad4_row1_col10, #T_90ad4_row4_col11, #T_90ad4_row9_col4, #T_90ad4_row12_col8, #T_90ad4_row15_col7, #T_90ad4_row21_col9 {
#   color: limegreen;
#   font-weight: bold;
#   text-align: center;
# }
# #T_90ad4_row5_col9, #T_90ad4_row9_col5, #T_90ad4_row10_col10, #T_90ad4_row12_col4, #T_90ad4_row21_col3, #T_90ad4_row21_col7, #T_90ad4_row22_col6, #T_90ad4_row22_col8, #T_90ad4_row22_col11, #T_90ad4_row23_col2 {
#   color: lightcoral;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_90ad4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90ad4_level0_col0" class="col_heading level0 col0" >Player</th>
#       <th id="T_90ad4_level0_col1" class="col_heading level0 col1" >Dominance Quotient</th>
#       <th id="T_90ad4_level0_col2" class="col_heading level0 col2" >Avg Score</th>
#       <th id="T_90ad4_level0_col3" class="col_heading level0 col3" >Goals Per Game</th>
#       <th id="T_90ad4_level0_col4" class="col_heading level0 col4" >Assists Per Game</th>
#       <th id="T_90ad4_level0_col5" class="col_heading level0 col5" >Saves Per Game</th>
#       <th id="T_90ad4_level0_col6" class="col_heading level0 col6" >Shots Per Game</th>
#       <th id="T_90ad4_level0_col7" class="col_heading level0 col7" >Shooting %</th>
#       <th id="T_90ad4_level0_col8" class="col_heading level0 col8" >Demos Inf. Per Game</th>
#       <th id="T_90ad4_level0_col9" class="col_heading level0 col9" >Demos Taken Per Game</th>
#       <th id="T_90ad4_level0_col10" class="col_heading level0 col10" >Big Boost Stolen</th>
#       <th id="T_90ad4_level0_col11" class="col_heading level0 col11" >Small Boost Stolen</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90ad4_leve
