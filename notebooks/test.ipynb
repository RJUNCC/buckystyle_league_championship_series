# %%
import requests
import pandas as pd
import os
import sys

current_dir = os.path.dirname(os.path.abspath("__file__"))
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))

if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)
from config.config import Config

# %%
config = Config()

# %%
def fetch_player_data(group_id, token=config._ballchasing_token):
        url = f"https://ballchasing.com/api/groups/{group_id}"
        headers = {"Authorization": token}
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()
        df = pd.json_normalize(data, record_path=["players"])
        return df

# %%
df = fetch_player_data(config.current_group_id)

# %%
df = pd.read_parquet("../data/parquet/season_3_all_data.parquet")

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#            Player             Team  Games  Avg Score  Goals Per Game  \
# 0          Ankles        FLOPSTARS     39  256.05127        0.435897
# 1          Aryba.  POWERPUFF GIRLS     35  384.00000        0.942857
# 2             Bax   AX STREET BOYS     34  360.02942        0.558824
# 3        Distill?        FLOPSTARS     39  270.69232        0.717949
# 4            Duri  POWERPUFF GIRLS     35  444.28570        1.000000
# 5        Elakrity   AX STREET BOYS     34  234.50000        0.441176
# 6           Elhon      FLOWBERRIES     18  335.72223        0.777778
# 7        Imminent              IRS     34  539.73530        1.176471
# 8          Kyzeke   AX STREET BOYS     34  345.97058        0.441176
# 9      LKD Kicker      LOS GRINGOS      4  358.50000        1.250000
# 10       Niall IV        CANADIANS     32  418.37500        1.031250
# 11    Paperclip94      LOS GRINGOS     31  487.09677        1.161290
# 12        Pullis.        CANADIANS     32  285.21875        0.343750
# ...
