# %%
import pandas as pd

df = pd.read_parquet('../data/parquet/season_3_player_data.parquet')

# %%
df
# Out:
#            Player             Team  Dominance Quotient  Avg Score  \
# 1      jeridinho.        BIG THREE                66.6  564.42310
# 2       Immininho              IRS                64.6  535.67740
# 3            desi        FLOPSTARS                64.4  542.48720
# 4             nyk      FLOWBERRIES                62.8  574.28570
# 5            Duri  POWERPUFF GIRLS                62.6  485.66666
# 6          Aryba.  POWERPUFF GIRLS                54.8  439.66666
# 7     Paperclip94      LOS GRINGOS                54.0  478.63635
# 8         VaredzZ  SCHOOL SHOOTERS                52.2  463.47370
# 9           Elhon      FLOWBERRIES                50.6  374.28570
# 10     buckystyle       DECHAMBROS                48.0  393.87500
# 11       Niall IV        CANADIANS                46.0  418.37500
# 12           Xero       DECHAMBROS                43.8  366.55000
# 13            Ray              IRS                42.2  361.41934
# ...
